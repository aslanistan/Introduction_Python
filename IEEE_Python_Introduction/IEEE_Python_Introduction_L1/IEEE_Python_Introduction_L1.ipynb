# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# # IEEE Future Networks World Forum - Session 1: Introduction to Python Programming - L1
#
# Python is an Object Oriented Programmning. When we use Python (IDE, Notebook, etc.), we need to consider that.
#
# ### Part I - How to use Python:
#
# Before getting started, we may want to decide which IDEs and text editors to use for th course. We will be using Anaconda Python ditrubution, Jupyter Notebooks and Visual Studio Code for the class. You may use PyCharm, Python IDE, Sublime or any other IDE and text editor you want.
# When we write a program in C/C++, we have to compile it. Compilation involves building step (manually compiled) and rebuilding if there is any changes are done in the program. These are four steps of Compilation :
#
#  * Preprocessing
#  * Compiling
#  * Assembly
#  * Linking
#
# For the most part, Python is an interpreted language and not a compiled one, although compilation is a step. Python code, written in .py file is first compiled to what is called bytecode which is stored with a .pyc or .pyo format. Instead of translating source code to machine code like C++, Python code it translated to bytecode. This bytecode is a low-level set of instructions that can be executed by an interpreter. Python is a platform-independent language. Python is a dynamic typing language and the interpreter checks the validity of the variable types and operations performed.
#
# ### ```Example ```
#
# Adding two numbers:
#
# ```C
# #include<stdio.h>
#
# int main() {
#    int a = 3;
#    int b = 4;
#    int sum;
#
#    sum = a + b;
#
#    printf("Sum : %d", sum);
#
#    return(0);
# }
# ```

# %%
# !clang add_num.c -o add_num

# %%
# !./add_num
# Out:
# Sum : 7

# %%
a=3
b=4
print(f'Sum : {a+b}')
# Out:
# Sum : 7

# %% [markdown]
# ```C
# #include<stdio.h>
#
# int main() {
#    float a = 3;
#    float b = 4;
#    float sum;
#
#    sum = a + b;
#
#    printf("Sum : %d", sum);
#
#    return(0);
# }
# ```

# %%
# !clang add_num_f.c -o add_num
# Out:
# add_num_f.c:10:23: warning: format specifies type 'int' but the argument has
#       type 'float' [-Wformat]
#    printf("Sum : %d", sum);
#                  ~~   ^~~
#                  %f
# 1 warning generated.

# %%
# !./add_num
# Out:
# Sum : -459335536

# %% [markdown]
# ```C
# #include<stdio.h>
#
# int main() {
#    float a = 3;
#    float b = 4;
#    float sum;
#
#    sum = a + b;
#
#    printf("Sum : %f", sum);
#
#    return(0);
# }
# ```

# %%
# !clang add_num_f2.c -o add_num

# %%
# !./add_num
# Out:
# Sum : 7.000000

# %%
a=3
b=4
print(f'Sum : {a+b:.4f}')
# Out:
# Sum : 7.0000

# %% [markdown]
# ### Part II - Python Libraries: Python Standard Library & List of Important Libraries
#
# A Python library is a reusable chunk of code that you may want to include in your programs/ projects. A library is a collection of modules. A package is a library that can be installed using a package manager.
#
# A Python module is a file with some Python code, and a package is a directory for sub packages and modules.
#
# It contains data types that would normally be considered part of the “core” of a language, such as numbers and lists. For these types, the Python language core defines the form of literals and places some constraints on their semantics, but does not fully define the semantics. (On the other hand, the language core does define syntactic properties like the spelling and priorities of operators.)
#
# The library also contains built-in functions and exceptions — objects that can be used by all Python code without the need of an import statement. Some of these are defined by the core language, but many are not essential for the core semantics and are only described here.
#
# < More info https://docs.python.org/3/library/ >

# %% [markdown]
# ### Built-in Constants
#
# A small number of constants live in the built-in namespace. They are:
#
# ```False``` : The false value of the bool type. Assignments to False are illegal and raise a SyntaxError.
#
# ```True``` : The true value of the bool type. Assignments to True are illegal and raise a SyntaxError.
#
# ```None``` : The sole value of the type NoneType. None is frequently used to represent the absence of a value, as when default arguments are not passed to a function. Assignments to None are illegal and raise a SyntaxError.
#
# < More info https://docs.python.org/3/library/constants.html#constants-added-by-the-site-module >

# %%
True = 2
# Out:
#   File "<ipython-input-33-da3e5402d318>", line 1
#     True = 2
#     ^
# SyntaxError: cannot assign to True

# %%
a = True
b = False
c = None

print(a+b)
print(c)
# Out:
# 1
# None

# %% [markdown]
# ### Built-in Functions
#
# |                                                                                           |                                                                                    |                                                                                       |                                                                                |                                                                                             |
# | ------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------- | ---------------------------------------------------------------------------------------- | ---------------------------------------------------------------------------------- | ---------------------------------------------------------------------------------------------- |
# | [abs()](https://docs.python.org/3/library/functions.html#abs "abs")                         | [delattr()](https://docs.python.org/3/library/functions.html#delattr "delattr")       | [hash()](https://docs.python.org/3/library/functions.html#hash "hash")                   | [memoryview()](https://docs.python.org/3/library/functions.html#func-memoryview)   | [set()](https://docs.python.org/3/library/functions.html#func-set)                             |
# | [all()](https://docs.python.org/3/library/functions.html#all "all")                         | [dict()](https://docs.python.org/3/library/functions.html#func-dict)                  | [help()](https://docs.python.org/3/library/functions.html#help "help")                   | [min()](https://docs.python.org/3/library/functions.html#min "min")                | [setattr()](https://docs.python.org/3/library/functions.html#setattr "setattr")                |
# | [any()](https://docs.python.org/3/library/functions.html#any "any")                         | [dir()](https://docs.python.org/3/library/functions.html#dir "dir")                   | [hex()](https://docs.python.org/3/library/functions.html#hex "hex")                      | [next()](https://docs.python.org/3/library/functions.html#next "next")             | [slice()](https://docs.python.org/3/library/functions.html#slice "slice")                      |
# | [ascii()](https://docs.python.org/3/library/functions.html#ascii "ascii")                   | [divmod()](https://docs.python.org/3/library/functions.html#divmod "divmod")          | [id()](https://docs.python.org/3/library/functions.html#id "id")                         | [object()](https://docs.python.org/3/library/functions.html#object "object")       | [sorted()](https://docs.python.org/3/library/functions.html#sorted "sorted")                   |
# | [bin()](https://docs.python.org/3/library/functions.html#bin "bin")                         | [enumerate()](https://docs.python.org/3/library/functions.html#enumerate "enumerate") | [input()](https://docs.python.org/3/library/functions.html#input "input")                | [oct()](https://docs.python.org/3/library/functions.html#oct "oct")                | [staticmethod()](https://docs.python.org/3/library/functions.html#staticmethod "staticmethod") |
# | [bool()](https://docs.python.org/3/library/functions.html#bool "bool")                      | [eval()](https://docs.python.org/3/library/functions.html#eval "eval")                | [int()](https://docs.python.org/3/library/functions.html#int "int")                      | [open()](https://docs.python.org/3/library/functions.html#open "open")             | [str()](https://docs.python.org/3/library/functions.html#func-str)                             |
# | [breakpoint()](https://docs.python.org/3/library/functions.html#breakpoint "breakpoint")    | [exec()](https://docs.python.org/3/library/functions.html#exec "exec")                | [isinstance()](https://docs.python.org/3/library/functions.html#isinstance "isinstance") | [ord()](https://docs.python.org/3/library/functions.html#ord "ord")                | [sum()](https://docs.python.org/3/library/functions.html#sum "sum")                            |
# | [bytearray()](https://docs.python.org/3/library/functions.html#func-bytearray)              | [filter()](https://docs.python.org/3/library/functions.html#filter "filter")          | [issubclass()](https://docs.python.org/3/library/functions.html#issubclass "issubclass") | [pow()](https://docs.python.org/3/library/functions.html#pow "pow")                | [super()](https://docs.python.org/3/library/functions.html#super "super")                      |
# | [bytes()](https://docs.python.org/3/library/functions.html#func-bytes)                      | [float()](https://docs.python.org/3/library/functions.html#float "float")             | [iter()](https://docs.python.org/3/library/functions.html#iter "iter")                   | [print()](https://docs.python.org/3/library/functions.html#print "print")          | [tuple()](https://docs.python.org/3/library/functions.html#func-tuple)                         |
# | [callable()](https://docs.python.org/3/library/functions.html#callable "callable")          | [format()](https://docs.python.org/3/library/functions.html#format "format")          | [len()](https://docs.python.org/3/library/functions.html#len "len")                      | [property()](https://docs.python.org/3/library/functions.html#property "property") | [type()](https://docs.python.org/3/library/functions.html#type "type")                         |
# | [chr()](https://docs.python.org/3/library/functions.html#chr "chr")                         | [frozenset()](https://docs.python.org/3/library/functions.html#func-frozenset)        | [list()](https://docs.python.org/3/library/functions.html#func-list)                     | [range()](https://docs.python.org/3/library/functions.html#func-range)             | [vars()](https://docs.python.org/3/library/functions.html#vars "vars")                         |
# | [classmethod()](https://docs.python.org/3/library/functions.html#classmethod "classmethod") | [getattr()](https://docs.python.org/3/library/functions.html#getattr "getattr")       | [locals()](https://docs.python.org/3/library/functions.html#locals "locals")             | [repr()](https://docs.python.org/3/library/functions.html#repr "repr")             | [zip()](https://docs.python.org/3/library/functions.html#zip "zip")                            |
# | [compile()](https://docs.python.org/3/library/functions.html#compile "compile")             | [globals()](https://docs.python.org/3/library/functions.html#globals "globals")       | [map()](https://docs.python.org/3/library/functions.html#map "map")                      | [reversed()](https://docs.python.org/3/library/functions.html#reversed "reversed") | [\_\_import\_\_()](https://docs.python.org/3/library/functions.html#__import__ "__import__")   |
# | [complex()](https://docs.python.org/3/library/functions.html#complex "complex")             | [hasattr()](https://docs.python.org/3/library/functions.html#hasattr "hasattr")       | [max()](https://docs.python.org/3/library/functions.html#max "max")                      | [round()](https://docs.python.org/3/library/functions.html#round "round")          |                                                                                                |

# %%
print(abs(-3))
print(float(-3))
print(sum([-3,3,4,5,0]))
print(max([-3,3,4,5,0]))
print(bool([0,0,0,0,0]))
# Out:
# 3
# -3.0
# 9
# 5
# True

# %% [markdown]
# ### Functions and Classes (Just an intro)
#
# ```Python
# def square_num(x):
#     return x*x
# ```
#
# ```Python
# class square_num:
#     pass
# ```
# We will use functions for most of the exercises. You need to learn basics of the functions. We will have full introduction to functions later weeks.
#
# Also Pyhton is OOP and when you create as simple as variables you create objects.

# %%
a = 3
from IPython.display import Image
Image(filename='001.png',width = 200, height = 300)

# %%
print(a.denominator)
print(a.bit_length)
print(a.bit_length())
# Out:
# 1
# <built-in method bit_length of int object at 0x10c945970>
# 2

# %%
a = 'Hello'

# %%
from IPython.display import Image
Image(filename='002.png',width = 200, height = 300)

# %%
a.upper()
a.endswith('o')
# Out:
# True

# %%
# Example

a = complex(3,2)
a
# Out:
# (3+2j)

# %%
from IPython.display import Image
Image(filename='003.png',width = 200, height = 300)

# %%
a.real
# Out:
# 3.0

# %%
a.conjugate()
# Out:
# (3-2j)

# %%
abs(a)
# Out:
# 3.605551275463989

# %%
type(a)
# Out:
# complex

# %% [markdown]
# ### Function Examples
#
# Function are similar to mathematical functions. The usual syntax for defining a Python function is as follows:
#
# ```Python
# def <function_name>([<parameters>]):
#     <statement(s)>
#     return z
# ```
# Assume we are calculating ```z = f(x,y)``` and we can write (assume function z = 2x + y/x)
#
# ```Python
# def f(x,y):
#     z = 2*x+y/x
#     return z
# ```
# Python operates with indentation to group elements.
#
# ##### Example: Write a function that calculates cube root of a number
#
# ```Python
# def cube_cal(x):
#     return x**3
# ```

# %% [markdown]
# ### How to import modules/libraries
#
# Assume we will write a python function that calculates area of a circle.
#
# $$ Area = \pi \times r^2 $$

# %%
pi  # not a built-in constant. Where can we find it? 

help(pi)
dir(math)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-7198a862fc76> in <module>
# ----> 1 pi  # not a built-in constant. Where can we find it?
#       2
#       3 help(pi)
#       4 dir(math)
#
# NameError: name 'pi' is not defined

# %%
import math
# dir(__builtins__)
# help(math)
# dir(math)
# math.

# %%
from IPython.display import Image
Image(filename='004.png',width = 200, height = 300)

# %%
math.pi
# Out:
# 3.141592653589793

# %%
import math as mt # preferred method

mt.pi
# Out:
# 3.141592653589793

# %%
from math import * # not preferred

pi
# Out:
# 3.141592653589793

# %%
from math import pi # if you need just pi

pi
# Out:
# 3.141592653589793

# %%
from math import pi, log2 # if you need just pi and log2

# %%
log2(8), pi
# Out:
# (3.0, 3.141592653589793)

# %%
import os
os.sys.float_info
# Out:
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)

# %%
import numbers
issubclass(numbers.Real, numbers.Complex)
# Out:
# True

# %%
a=2
issubclass(numbers.Real, numbers.Complex)
isinstance(3.14, numbers.Complex)
isinstance(3.14, numbers.Real)
isinstance(3.14, numbers.Integral)
# Out:
# False

# %%
2+2
# Out:
# 4

# %%
# Miami: 25° 45’ 42.054” N, 80° 11’ 30.438” W

# Latitude / Longitude Conversion
# Degrees Minutes Seconds to Decimal Degree
def fL(x,y,z):
    return x+y/60+z/3600

fL(80,11,30.438)
# Out:
# 80.19178833333334

# %%
x
if abs(x) <=0.001:
    print('cool')

# %% [markdown]
# ### Practice - Python as Calculator
#
#
# ##### **Example 1)** Calculate $f(y) = \frac{3 \times 4}{4^3 + 3 \times y}$
#
# ##### **Example 2)** Write  $f(y) = \frac{3 \times 4}{4^3 + 3 \times y}$ as a function and calculate if for x=1,2,3.
#
# ##### **Example 3)** Calculate required number of selection bits for 13-1 Mux.
#
# ##### **Example 4)** Calculate $f(x,y) = ln(x) + log_2(3x)^y$
#
# ##### **Example 5)** Write $f(x,y) = ln(x) + log_2(3x)^y$ as a function and calculate if for x=1,2,3 and y = 3,2,1.
#
# ##### **Example 6)** Calculate $x = 4! + 3 log_4(14) + e^{log_7(33)} + log_2(3)^3$
#
# ##### **Example 7)** Calculate $(1+5^2)-16\big(\frac{1}{2}\big)^3$
#
# ##### **Example 8)** Calculate $(3+2)^2-7$
#
# ##### **Example 9)** Calculate $\frac{3}{4}\big(2^3+4^2\big)$
#
# ##### **Example 10)** Write a function that calculates average of two numbers [Hint: $f(x,y) = \frac{x+y}{2}$]

# %% [markdown]
# ## Python Keywords
#
# Python keywords are special reserved words that have specific meanings and purposes and can’t be used for anything but those specific purposes. Python keywords are different from Python’s ```built-in functions and types```. The built-in functions and types are also always available, but they aren’t as restrictive as the keywords in their usage.
#
# ```python
# pass=2  # will create SyntaxError
# bytes=2 # will be fine
# ```
#
# There are thirty-five keywords in Python 3.8.
#
# |   |   |   |   |   |
# |---|---|---|---|---|
# False|await|else|import|pass
# None|break|except|in|raise
# True|class|finally|is|return
# and|continue|for|lambda|try
# as|def|from|nonlocal|while
# assert|del|global|not|with
# async|elif|if|or|yield

# %%
help("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
help("pass")
# Out:
# The "pass" statement
# ********************
#
#    pass_stmt ::= "pass"
#
# "pass" is a null operation — when it is executed, nothing happens. It
# is useful as a placeholder when a statement is required syntactically,
# but no code needs to be executed, for example:
#
#    def f(arg): pass    # a function that does nothing (yet)
#
#    class C: pass       # a class with no methods (yet)

# %%
import keyword
keyword.kwlist
len(keyword.kwlist)
# Out:
# 35

# %%
# Value Keywords: True, False, None

a = False   # bool(0) -> only 0, "", [], and {} false
a = bool(0)
a = bool()
a = bool([])  # [] -> list
a = bool(()) # () -> tiple
a = bool({}) # Set or dict
a = bool("") # String
a is False
# Out:
# True

# %%
a = "Go Yankees!"
a is True
# bool(a) is True
# Out:
# False

# %%
import matplotlib.pyplot as plt

x = [2010,2011,2012,2013,2014,2015]
y = [12,34,12,43,12,33]
z = [None,4,2,None,2,23]

plt.plot(x,y,x,z)

# %%
# The None Keyword: The Python keyword None represents no value.

def coolf():
    print("Cool!")

a = coolf()
print(a)
# Out:
# Cool!
# None

# %%
def coolf():
     return "Cool!"
a = coolf()
print(a)
# Out:
# Cool!

# %% [markdown]
# ## Operator Keywords: and, or, not, in, is
#
# **Math Operator**|**Other Languages**|**Python Keyword**
# -----|-----|-----
# AND|&&|and
# OR | \| | or
# NOT|!|not
# CONTAINS| |in
# IDENTITY|===|is

# %%
bool(1) and bool(3)
bool(1) or bool(0)
not bool(1)
# Out:
# False

# %%
# <element> in <container>

a = 'Cool!'
'l' in a
'L' in a

x = [1,2,3,4]
2 in x

for number in x:
    print(number)
# Out:
# 1
# 2
# 3
# 4

# %%
# he is Keyword: Python’s is keyword is an identity check. 
# This is different from the == operator, which checks for equality. 
# a is b ->  This will return True if a is the exact same object in memory as b, 
# or else it will return False.

a = 2
print(id(a))
b = 2
print(id(b))

a is b
# Out:
# 4327166608
# 4327166608
# True

# %%
# import copy
a = 2
print(id(a))
b = a
print(id(b))
a is b
# Out:
# 4327166608
# 4327166608
# True

# %%
a = 2
print(id(a))
b = 4/2
print(id(b))
a is not b
# Out:
# 4327166608
# 140587171398768
# True

# %%
# Out:
# True

# %% [markdown]
# ## References
#
# * [**Intro to Python for Computer Science and Data Science: Learning to Program with AI, Big Data and the Cloud**](https://amzn.to/2VvdnxE).
#
# * https://realpython.com/
